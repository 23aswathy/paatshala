# %% [markdown]
# <a href="https://colab.research.google.com/github/23aswathy/paatshala/blob/main/Aswathy_G_Assignment_Hypothesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the libraries#

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the data set#
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7086c678-f06b-4e68-a4cc-119a5f63d8f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7086c678-f06b-4e68-a4cc-119a5f63d8f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#reading the file using pandas

# %%
data=pd.read_csv('Sales_add.csv')

# %%
data
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# ...

# %%
#formulation of hypothesis#
#As the sample size is less than 30,the hypothesis can be formulated and concluded upon a two sample t-test

#H0:sales decreased after digital marketing 
#H1:sales increased after digital marketing

# %%
data.columns
# Out:
# Index(['Month', 'Region', 'Manager', 'Sales_before_digital_add(in $)',
#        'Sales_After_digital_add(in $)'],
#       dtype='object')

# %%
data=data.rename(columns={'Sales_before_digital_add(in $)':'Sales before'})

# %%
data
# Out:
#        Month      Region      Manager  Sales before  \
# 0    Month-1  Region - A  Manager - A        132921
# 1    Month-2  Region - A  Manager - C        149559
# 2    Month-3  Region - B  Manager - A        146278
# 3    Month-4  Region - B  Manager - B        152167
# 4    Month-5  Region - C  Manager - B        159525
# 5    Month-6  Region - A  Manager - B        137163
# 6    Month-7  Region - C  Manager - C        130625
# 7    Month-8  Region - A  Manager - A        131140
# 8    Month-9  Region - B  Manager - C        171259
# 9   Month-10  Region - C  Manager - B        141956
# 10  Month-11  Region - B  Manager - C        159339
# 11  Month-12  Region - A  Manager - A        178939
# 12  Month-13  Region - B  Manager - A        145062
# 13  Month-14  Region - A  Manager - A        151514
# 14  Month-15  Region - C  Manager - A        147463
# 15  Month-16  Region - A  Manager - B        177195
# 16  Month-17  Region - A  Manager - C        140862
# ...

# %%
data=data.rename(columns={'Sales_After_digital_add(in $)':'Sales after'})

# %%
data
# Out:
#        Month      Region      Manager  Sales before  Sales after
# 0    Month-1  Region - A  Manager - A        132921       270390
# 1    Month-2  Region - A  Manager - C        149559       223334
# 2    Month-3  Region - B  Manager - A        146278       244243
# 3    Month-4  Region - B  Manager - B        152167       231808
# 4    Month-5  Region - C  Manager - B        159525       258402
# 5    Month-6  Region - A  Manager - B        137163       256948
# 6    Month-7  Region - C  Manager - C        130625       222106
# 7    Month-8  Region - A  Manager - A        131140       230637
# 8    Month-9  Region - B  Manager - C        171259       226261
# 9   Month-10  Region - C  Manager - B        141956       193735
# 10  Month-11  Region - B  Manager - C        159339       203175
# 11  Month-12  Region - A  Manager - A        178939       276279
# 12  Month-13  Region - B  Manager - A        145062       205180
# ...

# %%
from scipy.stats import ttest_ind

# %%
data1=data['Sales before']
data2=data['Sales after']
data1
# Out:
# 0     132921
# 1     149559
# 2     146278
# 3     152167
# 4     159525
# 5     137163
# 6     130625
# 7     131140
# 8     171259
# 9     141956
# 10    159339
# 11    178939
# 12    145062
# 13    151514
# 14    147463
# 15    177195
# 16    140862
# 17    167996
# 18    132135
# 19    152493
# 20    147425
# 21    130263
# Name: Sales before, dtype: int64

# %%
data1.mean()
# Out:
# 149239.95454545456

# %%
data2
# Out:
# 0     270390
# 1     223334
# 2     244243
# 3     231808
# 4     258402
# 5     256948
# 6     222106
# 7     230637
# 8     226261
# 9     193735
# 10    203175
# 11    276279
# 12    205180
# 13    253131
# 14    229336
# 15    187305
# 16    234908
# 17    191517
# 18    227040
# 19    212579
# 20    263388
# 21    243020
# Name: Sales after, dtype: int64

# %%
data2.mean()
# Out:
# 231123.72727272726

# %%
t_test1,p_value1=ttest_ind(data1,data2)
t_test1
# Out:
# -12.995084451110877

# %%
p_value1
# Out:
# 2.614368006904645e-16

# %%
if p_value<0.05:
  print('reject H0')
else:
  print('H0 accept')
# Out:
# reject H0

# %%
#As the observed p_value is less than 0.05 the null hypothesis is rejected and hence it  seems sales to be increased after digital marketing

# %%
plt.bar(data['Region'],data['Sales after'])
# Out:
# <BarContainer object of 22 artists>

# %%
#region A got greater sales after the digital marketing.

# %%
plt.bar(data['Manager'],data['Sales after'])
# Out:
# <BarContainer object of 22 artists>

# %%
The digital marketing measures of Manager A had improved the sales.
