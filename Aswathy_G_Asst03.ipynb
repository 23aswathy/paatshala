# %% [markdown]
# <a href="https://colab.research.google.com/github/23aswathy/paatshala/blob/main/Aswathy_G_Asst03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2a06f1f1-dfcd-49e3-8549-2503104b53a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a06f1f1-dfcd-49e3-8549-2503104b53a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('StudentsPerformance.csv')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
g=data.gender.value_counts().index
g
# Out:
# Index(['female', 'male'], dtype='object')

# %%
#1. Find out how many males and females participated in the test.

# %%
c=data.gender.value_counts()
c
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
#2. What do you think about the students' parental level of education?

# %%
plt.hist(data['parental level of education'])
plt.xticks(rotation=90)
plt.show()

# %%
#The histogram result sounds like majority of the parents had earned college level education and a very few have completed  master's degree.

# %%
#3. Who scores the most on a.average for math, reading and writing based on gender and test preparation course#

# %%
df=data[['race/ethnicity','math score']].groupby(['race/ethnicity','math score']).max
df()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
#based on gender#

# %%
df2=data.groupby(['gender','math score']).sum()
df2
# Out:
#                    reading score  writing score
# gender math score
# female 0                      17             10
#        8                      24             23
#        11                     38             32
#        13                     41             51
#        18                     32             28
# ...                          ...            ...
# male   96                     90             92
#        97                    354            347
#        98                    173            180
#        99                     87             81
#        100                   393            378
#
# [153 rows x 2 columns]

# %%
#males are having higher math score when compared to females

# %%
df2.describe()
# Out:
#        reading score  writing score
# count     153.000000     153.000000
# mean      452.254902     445.222222
# std       376.526726     373.828701
# min        17.000000      10.000000
# 25%       146.000000     138.000000
# 50%       393.000000     378.000000
# 75%       706.000000     701.000000
# max      2114.000000    2099.000000

# %%
data.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
dfm=data['math score']
dfm
# Out:
# 0        0
# 1        8
# 2       18
# 3       11
# 4       22
#       ...
# 995     99
# 996    100
# 997    100
# 998    100
# 999    100
# Name: math score, Length: 1000, dtype: int64

# %%
dfm.max()
# Out:
# 100

# %%
dfr=data.groupby(['gender','reading score']).size()
dfr
# Out:
# gender  reading score
# female  17               1
#         24               1
#         29               1
#         31               1
#         32               1
#                         ..
# male    93               1
#         95               1
#         96               3
#         97               1
#         100              3
# Length: 134, dtype: int64

# %%
dfr.max(axis=0)
# Out:
# 23

# %%
dfw=data.groupby(['gender','writing score']).size()
dfw
# Out:
# gender  writing score
# female  10               1
#         23               1
#         27               1
#         28               1
#         30               1
#                         ..
# male    92               4
#         93               1
#         95               1
#         99               1
#         100              1
# Length: 136, dtype: int64

# %%
dfw.max(axis=0)
# Out:
# 24

# %%
dt=data[['test preparation course','math score']].groupby(['test preparation course','math score']).max
dt()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
dtr=data[['test preparation course','reading score']].groupby(['test preparation course','reading score']).size
dtr()
# Out:
# test preparation course  reading score
# completed                37               1
#                          40               1
#                          41               3
#                          42               1
#                          43               1
#                                          ..
# none                     94               1
#                          95               5
#                          96               1
#                          97               2
#                          100              6
# Length: 131, dtype: int64

# %%
dtr=data[['test preparation course','writing score']].groupby(['test preparation course','writing score']).max
dtr()
# Out:
# Empty DataFrame
# Columns: []
# ...
